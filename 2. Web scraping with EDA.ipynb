# %% [markdown]
# # Read CSV File

# %%
import pandas as pd
import numpy as np

# %%
Cars = pd.read_csv('Cars_dataset.csv')
Cars
# Out:
#                              Car Name  min_price_inLakhs  max_price_inLakhs  \
# 0                       Hyundai Creta               12.7               24.2
# 1                           Kia Sonet                8.2               18.8
# 2                           Kia Syros                9.7               18.7
# 3                Maruti Suzuki Brezza                9.2               15.0
# 4          Maruti Suzuki Grand Vitara               12.4               22.5
# ..                                ...                ...                ...
# 643                     Tata Nexon EV               13.3               18.4
# 644                Hyundai i20 N Line               10.4               14.8
# 645                     Toyota Glanza                7.4               10.4
# 646  Maruti Suzuki Ertiga (2022-2025)                9.9               14.9
# 647                 Maruti Suzuki XL6               13.3               16.6
#
#     Fuel Type  Car Variants Transmission
# ...

# %%
Cars.head()
# Out:
#                      Car Name  min_price_inLakhs  max_price_inLakhs Fuel Type  \
# 0               Hyundai Creta               12.7               24.2    Petrol
# 1                   Kia Sonet                8.2               18.8    Petrol
# 2                   Kia Syros                9.7               18.7    Petrol
# 3        Maruti Suzuki Brezza                9.2               15.0    Petrol
# 4  Maruti Suzuki Grand Vitara               12.4               22.5    Petrol
#
#    Car Variants Transmission
# 0            43       Manual
# 1            31       Manual
# 2            13       Manual
# 3            18       Manual
# 4            20       Manual

# %%
Cars.tail()
# Out:
#                              Car Name  min_price_inLakhs  max_price_inLakhs  \
# 643                     Tata Nexon EV               13.3               18.4
# 644                Hyundai i20 N Line               10.4               14.8
# 645                     Toyota Glanza                7.4               10.4
# 646  Maruti Suzuki Ertiga (2022-2025)                9.9               14.9
# 647                 Maruti Suzuki XL6               13.3               16.6
#
#     Fuel Type  Car Variants Transmission
# 643       NaN            18    Automatic
# 644    Petrol             4       Manual
# 645    Petrol             9       Manual
# 646    Petrol             9       Manual
# 647    Petrol             7       Manual

# %%
# Number of Columns
Cars.shape[1]
# Out:
# 6

# %%
# Number of rows
Cars.shape[0]
# Out:
# 648

# %%
# Datatype of the columns
Cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car Name           648 non-null    object
#  1   min_price_inLakhs  648 non-null    float64
#  2   max_price_inLakhs  648 non-null    float64
#  3   Fuel Type          594 non-null    object
#  4   Car Variants       648 non-null    int64
#  5   Transmission       648 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 30.5+ KB

# %%
# Total null values
Cars.isna().sum()
# Out:
# Car Name              0
# min_price_inLakhs     0
# max_price_inLakhs     0
# Fuel Type            54
# Car Variants          0
# Transmission          0
# dtype: int64

# %% [markdown]
# # Clean the Data

# %%
Cars.columns
# Out:
# Index(['Car Name', 'min_price_inLakhs', 'max_price_inLakhs', 'Fuel Type',
#        'Car Variants', 'Transmission'],
#       dtype='object')

# %%
Cars.rename(columns = {'Car Name' : 'Car_Name'}, inplace = True)

# %%
Cars
# Out:
#                              Car_Name  min_price_inLakhs  max_price_inLakhs  \
# 0                       Hyundai Creta               12.7               24.2
# 1                           Kia Sonet                8.2               18.8
# 2                           Kia Syros                9.7               18.7
# 3                Maruti Suzuki Brezza                9.2               15.0
# 4          Maruti Suzuki Grand Vitara               12.4               22.5
# ..                                ...                ...                ...
# 643                     Tata Nexon EV               13.3               18.4
# 644                Hyundai i20 N Line               10.4               14.8
# 645                     Toyota Glanza                7.4               10.4
# 646  Maruti Suzuki Ertiga (2022-2025)                9.9               14.9
# 647                 Maruti Suzuki XL6               13.3               16.6
#
#     Fuel Type  Car Variants Transmission
# ...

# %%
Cars.rename(columns = {'Fuel Type' : 'Fuel_Type'}, inplace = True)

# %%
Cars
# Out:
#                              Car_Name  min_price_inLakhs  max_price_inLakhs  \
# 0                       Hyundai Creta               12.7               24.2
# 1                           Kia Sonet                8.2               18.8
# 2                           Kia Syros                9.7               18.7
# 3                Maruti Suzuki Brezza                9.2               15.0
# 4          Maruti Suzuki Grand Vitara               12.4               22.5
# ..                                ...                ...                ...
# 643                     Tata Nexon EV               13.3               18.4
# 644                Hyundai i20 N Line               10.4               14.8
# 645                     Toyota Glanza                7.4               10.4
# 646  Maruti Suzuki Ertiga (2022-2025)                9.9               14.9
# 647                 Maruti Suzuki XL6               13.3               16.6
#
#     Fuel_Type  Car Variants Transmission
# ...

# %%
# Handling the missing values
Cars.isna().sum()
# Out:
# Car_Name              0
# min_price_inLakhs     0
# max_price_inLakhs     0
# Fuel_Type            54
# Car Variants          0
# Transmission          0
# dtype: int64

# %%
# Warnings are NOT errors, Code runs correctly ,Output is correct But Python gives suggestions or alerts - to avoid these we use warnings
import warnings
warnings.filterwarnings('ignore')

# %%
Cars['Fuel_Type'].fillna(Cars['Fuel_Type'].mode()[0], inplace = True)

# %%
Cars.isna().sum()
# Out:
# Car_Name             0
# min_price_inLakhs    0
# max_price_inLakhs    0
# Fuel_Type            0
# Car Variants         0
# Transmission         0
# dtype: int64

# %%
Cars.head()
# Out:
#                      Car_Name  min_price_inLakhs  max_price_inLakhs Fuel_Type  \
# 0               Hyundai Creta               12.7               24.2    Petrol
# 1                   Kia Sonet                8.2               18.8    Petrol
# 2                   Kia Syros                9.7               18.7    Petrol
# 3        Maruti Suzuki Brezza                9.2               15.0    Petrol
# 4  Maruti Suzuki Grand Vitara               12.4               22.5    Petrol
#
#    Car Variants Transmission
# 0            43       Manual
# 1            31       Manual
# 2            13       Manual
# 3            18       Manual
# 4            20       Manual
